# %% [markdown]
# Syntax natürlicher Sprachen, WS 2023/24
#
# # 06 - Aufgabenblatt

# %%
import nltk
from nltk import Tree
from nltk import DependencyGraph
from spacy import displacy
import spacy
from itertools import chain

# %%
def _tree_labeled(self, i):
    node = self.get_by_address(i)
    word, rel = node["word"], node["rel"]
    deps = sorted(chain.from_iterable(node["deps"].values()))
    return Tree(word + '(' + rel + ')', [self._tree_labeled(dep) for dep in deps]) if deps else word + '(' + rel + ')'

def tree_labeled(self):
    node = self.root
    word, rel = node["word"], node["rel"]
    deps = sorted(chain.from_iterable(node["deps"].values()))
    return Tree(word+'('+rel+')', [self._tree_labeled(dep) for dep in deps])

DependencyGraph._tree_labeled = _tree_labeled
DependencyGraph.tree_labeled = tree_labeled

def transform_nr_conll(sent_nr):
    sent_list = []
    for line in list(filter(None, sent_nr.split("\n"))):
        line_list = line.split(); line_list.pop(0); line_list.insert(1,"_")
        sent_list.append(" ".join([i for i in line_list[0:]]))
    return "\n".join([i for i in sent_list[0:]])

def displacy_dep_input(sent):
    deps = []
    for dep in sent.split('\n'):
        deps.append(dep.split())
    deps = [x for x in deps if x]
    ex, word_list, arc_list = [], [], []
    for index, dep in enumerate(deps):
        word_list.append({"text": dep[0], "tag": ""})
        line = index+1; head = int(dep[2]); label = dep[3]
        if head>line:
            start = index; end = head-1; direction = "left"
        else:
            start = head-1; end = index; direction = "right"
        if(label.lower() != "root"):
            arc_list.append({"start": start, "end": end, "label": label, "dir": direction})
    ex.append({"words": word_list,"arcs": arc_list})
    return ex

def show_dep_trees(sent_nr,style=1):
    sent = transform_nr_conll(sent_nr)
    dg = DependencyGraph(sent)
    if style == 0 or style == 2:
        tree_labeled = dg.tree_labeled()
        tree_labeled.pretty_print(unicodelines=True)   
    if style == 1 or style == 2:
        ex = displacy_dep_input(sent)
        html = displacy.render(ex, style="dep", manual=True, options={'distance':100})

# %% [markdown]
# ## Aufgabe 1 - Dependenzanalyse
#
# ### a) Analysieren Sie die Dependenzbeziehungen des folgenden Satzes im UD-Schema:
# *Ich kenne einen älteren Bruder von zwei sehr lebhaften Mädchen*

# %%
sent_nr = """
1 Ich 2 nsubj
2 kenne 0 ROOT
3 einen 5 det
4 aelteren 5 amod
5 Bruder 2 obj
6 von 10 case
7 zwei 10 nummod
8 sehr 9 advmod
9 lebhaften 10 amod
10 Mädchen 5 nmod
"""

show_dep_trees(sent_nr)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ca79717766044d1a8bc4287ce4489de5-0" class="displacy" width="1050" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Ich</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">kenne</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">einen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">aelteren</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">Bruder</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">von</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">zwei</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">sehr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">lebhaften</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">Mädchen</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-1" stroke-width="2px" d="M270,202.0 C270,102.0 440.0,102.0 440.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-2" stroke-width="2px" d="M370,202.0 C370,152.0 435.0,152.0 435.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-3" stroke-width="2px" d="M170,202.0 C170,52.0 445.0,52.0 445.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,204.0 L453.0,192.0 437.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-4" stroke-width="2px" d="M570,202.0 C570,52.0 945.0,52.0 945.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,204.0 L562,192.0 578,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-5" stroke-width="2px" d="M670,202.0 C670,102.0 940.0,102.0 940.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nummod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,204.0 L662,192.0 678,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-6" stroke-width="2px" d="M770,202.0 C770,152.0 835.0,152.0 835.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,204.0 L762,192.0 778,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-7" stroke-width="2px" d="M870,202.0 C870,152.0 935.0,152.0 935.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M870,204.0 L862,192.0 878,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ca79717766044d1a8bc4287ce4489de5-0-8" stroke-width="2px" d="M470,202.0 C470,2.0 950.0,2.0 950.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ca79717766044d1a8bc4287ce4489de5-0-8" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M950.0,204.0 L958.0,192.0 942.0,192.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### b) Analysieren Sie die Dependenzbeziehungen des folgenden Satzes im UD-Schema:
# *Fährt ein elektrisches Auto von Tesla schnell ?*

# %%
sent_nr = """
1 Fährt 0 ROOT
2 ein 4 det
3 elektrisches 4 amod
4 Auto 1 nsubj
5 von 6 case
6 Tesla 4 nmod
7 schnell 1 advmod
8 ? 1 punct
"""

show_dep_trees(sent_nr)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="8f87cf113a344c518f81e622c7d684a7-0" class="displacy" width="850" height="387.0" direction="ltr" style="max-width: none; height: 387.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Fährt</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">ein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">elektrisches</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Auto</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">von</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">Tesla</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">schnell</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="297.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">?</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f87cf113a344c518f81e622c7d684a7-0-0" stroke-width="2px" d="M170,252.0 C170,152.0 335.0,152.0 335.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f87cf113a344c518f81e622c7d684a7-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,254.0 L162,242.0 178,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f87cf113a344c518f81e622c7d684a7-0-1" stroke-width="2px" d="M270,252.0 C270,202.0 330.0,202.0 330.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f87cf113a344c518f81e622c7d684a7-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,254.0 L262,242.0 278,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f87cf113a344c518f81e622c7d684a7-0-2" stroke-width="2px" d="M70,252.0 C70,102.0 340.0,102.0 340.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f87cf113a344c518f81e622c7d684a7-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340.0,254.0 L348.0,242.0 332.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f87cf113a344c518f81e622c7d684a7-0-3" stroke-width="2px" d="M470,252.0 C470,202.0 530.0,202.0 530.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f87cf113a344c518f81e622c7d684a7-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">case</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M470,254.0 L462,242.0 478,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f87cf113a344c518f81e622c7d684a7-0-4" stroke-width="2px" d="M370,252.0 C370,152.0 535.0,152.0 535.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f87cf113a344c518f81e622c7d684a7-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M535.0,254.0 L543.0,242.0 527.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f87cf113a344c518f81e622c7d684a7-0-5" stroke-width="2px" d="M70,252.0 C70,52.0 645.0,52.0 645.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f87cf113a344c518f81e622c7d684a7-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M645.0,254.0 L653.0,242.0 637.0,242.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-8f87cf113a344c518f81e622c7d684a7-0-6" stroke-width="2px" d="M70,252.0 C70,2.0 750.0,2.0 750.0,252.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-8f87cf113a344c518f81e622c7d684a7-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">punct</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,254.0 L758.0,242.0 742.0,242.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Aufgabe 2 - Dependenzanalyse und Erweiterung
#
# ### a) Analysieren Sie die Dependenzbeziehungen dieses einfachen ditransitiven Satzes im UD-Schema:
# *Gestern übergab ein Briefträger ihr den Brief*

# %%
sent_nr = """
1 Gestern 2 advmod
2 übergab 0 ROOT
3 ein 4 det
4 Briefträger 2 nsubj
5 ihr 2 iobj
6 den 7 det
7 Brief 2 obj
"""

show_dep_trees(sent_nr)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="6209ce1feee64e6584d23afaf8219c45-0" class="displacy" width="750" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Gestern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">übergab</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">ein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Briefträger</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">ihr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">den</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Brief</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6209ce1feee64e6584d23afaf8219c45-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6209ce1feee64e6584d23afaf8219c45-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6209ce1feee64e6584d23afaf8219c45-0-1" stroke-width="2px" d="M270,202.0 C270,152.0 335.0,152.0 335.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6209ce1feee64e6584d23afaf8219c45-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6209ce1feee64e6584d23afaf8219c45-0-2" stroke-width="2px" d="M170,202.0 C170,102.0 340.0,102.0 340.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6209ce1feee64e6584d23afaf8219c45-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340.0,204.0 L348.0,192.0 332.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6209ce1feee64e6584d23afaf8219c45-0-3" stroke-width="2px" d="M170,202.0 C170,52.0 445.0,52.0 445.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6209ce1feee64e6584d23afaf8219c45-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">iobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,204.0 L453.0,192.0 437.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6209ce1feee64e6584d23afaf8219c45-0-4" stroke-width="2px" d="M570,202.0 C570,152.0 635.0,152.0 635.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6209ce1feee64e6584d23afaf8219c45-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,204.0 L562,192.0 578,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-6209ce1feee64e6584d23afaf8219c45-0-5" stroke-width="2px" d="M170,202.0 C170,2.0 650.0,2.0 650.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-6209ce1feee64e6584d23afaf8219c45-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,204.0 L658.0,192.0 642.0,192.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### b) Ersetzen Sie das durch ein Adverb realisierte Adverbial durch ein Kasus-Adverbial:

# %%
sent_nr = """
1 Dieser 2 det
2 Tage 3 obl
3 übergab 0 ROOT
4 ein 5 det
5 Briefträger 3 nsubj
6 ihr 3 iobj
7 den 8 det
8 Brief 3 obj
"""

show_dep_trees(sent_nr)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ac6b33ba915b44b1b82e2ef3a84f96c3-0" class="displacy" width="850" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Dieser</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">Tage</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">übergab</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">ein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">Briefträger</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">ihr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">den</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">Brief</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-1" stroke-width="2px" d="M170,202.0 C170,152.0 235.0,152.0 235.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obl</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M170,204.0 L162,192.0 178,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-2" stroke-width="2px" d="M370,202.0 C370,152.0 435.0,152.0 435.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M370,204.0 L362,192.0 378,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-3" stroke-width="2px" d="M270,202.0 C270,102.0 440.0,102.0 440.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M440.0,204.0 L448.0,192.0 432.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-4" stroke-width="2px" d="M270,202.0 C270,52.0 545.0,52.0 545.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">iobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M545.0,204.0 L553.0,192.0 537.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-5" stroke-width="2px" d="M670,202.0 C670,152.0 735.0,152.0 735.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M670,204.0 L662,192.0 678,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-6" stroke-width="2px" d="M270,202.0 C270,2.0 750.0,2.0 750.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ac6b33ba915b44b1b82e2ef3a84f96c3-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M750.0,204.0 L758.0,192.0 742.0,192.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ### c) Fügen Sie zu dem Ausgangssatz ein Genitiv-Attribut hinzu:

# %%
sent_nr = """
1 Gestern 2 advmod
2 übergab 0 ROOT
3 ein 4 det
4 Briefträger 2 nsubj
5 ihr 2 iobj
6 den 7 det
7 Brief 2 obj
8 des 9 det
10 Vaters 7 nmod
"""

show_dep_trees(sent_nr)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="ef061208a601441d9ca9f9f3a1620164-0" class="displacy" width="950" height="337.0" direction="ltr" style="max-width: none; height: 337.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">Gestern</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="150">übergab</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="150"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="250">ein</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="250"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">Briefträger</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="450">ihr</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="450"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="550">den</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="550"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">Brief</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="750">des</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750"></tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="247.0">
#     <tspan class="displacy-word" fill="currentColor" x="850">Vaters</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="850"></tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ef061208a601441d9ca9f9f3a1620164-0-0" stroke-width="2px" d="M70,202.0 C70,152.0 135.0,152.0 135.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ef061208a601441d9ca9f9f3a1620164-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">advmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,204.0 L62,192.0 78,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ef061208a601441d9ca9f9f3a1620164-0-1" stroke-width="2px" d="M270,202.0 C270,152.0 335.0,152.0 335.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ef061208a601441d9ca9f9f3a1620164-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M270,204.0 L262,192.0 278,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ef061208a601441d9ca9f9f3a1620164-0-2" stroke-width="2px" d="M170,202.0 C170,102.0 340.0,102.0 340.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ef061208a601441d9ca9f9f3a1620164-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M340.0,204.0 L348.0,192.0 332.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ef061208a601441d9ca9f9f3a1620164-0-3" stroke-width="2px" d="M170,202.0 C170,52.0 445.0,52.0 445.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ef061208a601441d9ca9f9f3a1620164-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">iobj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M445.0,204.0 L453.0,192.0 437.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ef061208a601441d9ca9f9f3a1620164-0-4" stroke-width="2px" d="M570,202.0 C570,152.0 635.0,152.0 635.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ef061208a601441d9ca9f9f3a1620164-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M570,204.0 L562,192.0 578,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ef061208a601441d9ca9f9f3a1620164-0-5" stroke-width="2px" d="M170,202.0 C170,2.0 650.0,2.0 650.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ef061208a601441d9ca9f9f3a1620164-0-5" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">obj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M650.0,204.0 L658.0,192.0 642.0,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ef061208a601441d9ca9f9f3a1620164-0-6" stroke-width="2px" d="M770,202.0 C770,152.0 835.0,152.0 835.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ef061208a601441d9ca9f9f3a1620164-0-6" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,204.0 L762,192.0 778,192.0" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-ef061208a601441d9ca9f9f3a1620164-0-7" stroke-width="2px" d="M670,202.0 C670,102.0 840.0,102.0 840.0,202.0" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-ef061208a601441d9ca9f9f3a1620164-0-7" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nmod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M840.0,204.0 L848.0,192.0 832.0,192.0" fill="currentColor"/>
# </g>
# </svg></span>

# %% [markdown]
# ## Aufgabe 3 - Satzglied-Funktion

# %% [markdown]
# ### a) Objekt vs Adverbial
#
# #### Gegeben sei folgender Satz, dessen drittes Satzglied den *geschehens*-Test nicht besteht.

# %%
sentence = ["er", "isst", "einen Apfel"]

sentence[0] + " " + sentence[1] + ", und das geschieht " + sentence[2]
# Out:
# 'er isst, und das geschieht einen Apfel'

# %% [markdown]
# #### Für welchen Typ von Dependent spricht dies (Angabe/Adjunkt oder Ergänzung/Komplement)?

# %%
# Komplement

# %% [markdown]
# #### Welche syntaktische Funktion hat das dritte Satzglied hier?  (Objekt oder Adverbial?) Testen Sie über Passivierung!

# %%
# Objekt (Ein Apfel wurde gegessen)

# %% [markdown]
# ### b) Präpositionalobjekt vs Adverbial
#
# #### Gegeben sei folgender Satz, dessen drittes Satzglied den *geschehens*-Test besteht (der Satz bleibt wohlgeformt).

# %%
sentence = ["er", "wartet", "auf dem Berggipfel"]

sentence[0] + " " + sentence[1] + ", und das geschieht " + sentence[2]
# Out:
# 'er wartet, und das geschieht auf dem Berggipfel'

# %% [markdown]
# #### Für welchen Typ von Dependent spricht dies (Angabe/Adjunkt oder Ergänzung/Komplement)?

# %%
# Adjunkt

# %% [markdown]
# #### Welche syntaktische Funktion hat das dritte Satzglied hier?  (Objekt oder Adverbial?) Testen Sie über Erfragbarkeit mit Pronominaladverb!

# %%
# Adverbial (Wo wartet er?)

# %% [markdown]
# ### c) Analysieren Sie die Dependenzbeziehungen des vorherigen Satzes im UD-Schema.
#
# #### Beachten Sie ggf. die Analysekonvention im UD-Schema für Präpositionalobjekte.

# %%
sent_nr = """
1 er
2 wartet 0 ROOT
3
"""

show_dep_trees(sent_nr)
